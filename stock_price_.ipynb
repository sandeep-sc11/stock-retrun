# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep-sc11/stock-retrun/blob/main/stock_price_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance cufflinks plotly numpy pandas

# %%
import pandas as pd
import numpy as np

import yfinance as yf

import cufflinks as cf
import plotly.io as pio

from datetime import date
from dateutil.relativedelta import relativedelta

# Configure plotly for Google Colab
cf.go_offline()
pio.renderers.default = "colab"

print("All libraries imported successfully ✅")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# All libraries imported successfully ✅

# %%
# Indian stock example
ticker = "TCS.NS"   # Reliance Industries (NSE)
weeks = 4

# Download stock data
stock_data = yf.download(
    ticker,
    start=date.today() - relativedelta(weeks=weeks),
    end=date.today(
))

# Display sample data
stock_data.head()
# Out:
# /tmp/ipython-input-4136170077.py:6: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2026-01-27  3158.000000  3175.000000  3130.000000  3175.000000  4279874
# 2026-01-28  3200.100098  3205.199951  3170.600098  3176.000000  2751234
# 2026-01-29  3144.399902  3200.100098  3125.600098  3200.100098  2457641
# 2026-01-30  3123.899902  3141.000000  3092.000000  3141.000000  3022068
# 2026-02-02  3169.600098  3198.000000  3134.000000  3198.000000  2636272

# %%
import plotly.graph_objects as go

# Extract the 'Close' price data for the specified ticker from stock_data
close_price = stock_data['Close']

# Create a Plotly Figure
fig = go.Figure(data=[go.Scatter(x=close_price.index, y=close_price['TCS.NS'], mode='lines', line=dict(color='Green'))])

# Update layout with titles
fig.update_layout(
    title='TCS Industries – Stock Price (Last 3 Months)',
    xaxis_title='Date',
    yaxis_title='Price (₹)'
)

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Calculate daily returns
daily_returns = close_price.pct_change()

# Remove first NaN value
daily_returns = daily_returns.dropna()

# Display first 5 rows
daily_returns.head()
# Out:
# Ticker        TCS.NS
# Date
# 2026-01-28  0.013331
# 2026-01-29 -0.017406
# 2026-01-30 -0.006520
# 2026-02-02  0.014629
# 2026-02-03  0.017573

# %%
import plotly.graph_objects as go

# Create daily returns plot
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=daily_returns.index,
        y=daily_returns['TCS.NS'], # Explicitly select the column
        mode='lines',
        name='Daily Returns'
    )
)

fig.update_layout(
    title='TCS Industries – Daily Returns',
    xaxis_title='Date',
    yaxis_title='Daily Return',
    yaxis_tickformat='.2%'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Calculate cumulative returns
cumulative_returns = (1 + daily_returns).cumprod()

# Display first 5 values
cumulative_returns.head()
# Out:
# Ticker        TCS.NS
# Date
# 2026-01-28  1.013331
# 2026-01-29  0.995693
# 2026-01-30  0.989202
# 2026-02-02  1.003673
# 2026-02-03  1.021311

# %%
# Plot cumulative returns
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=cumulative_returns.index,
        y=cumulative_returns['TCS.NS'], # Explicitly select the column
        mode='lines',
        name='Cumulative Returns'
    )
)

fig.update_layout(
    title='TCS Industries – Cumulative Returns',
    xaxis_title='Date',
    yaxis_title='Growth of ₹1 Invested'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
